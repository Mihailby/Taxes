# %% [markdown]
# 1040
# ___

# %%
# %pip install PyPDF2 reportlab pandas
import PyPDF2
from PyPDF2 import PdfReader, PdfWriter
import pandas as pd
from reportlab.pdfgen import canvas
from reportlab.lib.pagesizes import letter
import io
import os
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
def fill_pdf_form_fields(input_path, output_path, values):
    try:
        reader = PdfReader(input_path)
        writer = PdfWriter()
        for page in reader.pages: writer.add_page(page)
        if reader.get_fields(): writer.update_page_form_field_values(writer.pages[0], values)
        with open(output_path, 'wb') as f: writer.write(f)
        print(f"PDF saved to: {output_path}")
    except Exception as e:
        print(f"Error: {e}")

# %% [markdown]
# Fill PDF form fields (if PDF has fillable fields)

# %% [markdown]
# Example usage with sample data

# %%
# Sample data for one person
sample_data = {
    'Name': 'John Doe',
    'SSN 1': '123',
    'SSN 2': '45',
    'SSN 3': '6789',
    'Address Where Rented': '123 Main St, Apt 4B, New York, NY 10001'}

template_pdf_path = 'Schedule C (9-25) Fillable .pdf'
output_pdf_path = 'filled_form.pdf'
 
field_values = {
     'Name': sample_data['Name'],
     'SSN 1': sample_data['SSN 1'],
     'SSN 2': sample_data['SSN 2'],
     'SSN 3': sample_data['SSN 3'],
     'Address Where Rented': sample_data['Address Where Rented']}

fill_pdf_form_fields(template_pdf_path, output_pdf_path, field_values)
# Out:
# PDF saved to: filled_form.pdf

# %%
import pkg_resources

installed_packages = [d.project_name for d in pkg_resources.working_set]
if 'ipywidgets' in installed_packages:
    print("✅ ipywidgets is installed")
    
    # Get version
    version = pkg_resources.get_distribution("ipywidgets").version
    print(f"   Version: {version}")
else:
    print("❌ ipywidgets is NOT installed")
    print("Run: %pip install ipywidgets")

# %% [markdown]
# Helper function to find field names in PDF
